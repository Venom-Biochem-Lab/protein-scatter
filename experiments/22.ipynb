# %%
# how can I extract info from PDB?
# https://data.rcsb.org/redoc/index.html
import requests
import pandas as pd
from bs4 import BeautifulSoup
from tqdm import tqdm

# %%
def parse_after(string: str, after="&nbsp"):
	return string[string.index(after) + len(after):]

def get_pdb(code: str):
	entry_id = code
	req = requests.get(f"https://www.rcsb.org/structure/{entry_id}")
	parsed_html = BeautifulSoup(req.text)
	title = parsed_html.body.find('span', attrs={'id':'structureTitle'}).text
	classification = parsed_html.body.find('li', attrs={'id':'header_classification'}).text
	classification = parse_after(classification)
	organism = parsed_html.body.find('li', attrs={'id':'header_organism'}).text
	organism = parse_after(organism)
	return dict(
		title=title, classification=classification, organism=organism
	)
get_pdb("1RH7")
# Out:
# {'title': 'Crystal Structure of Resistin-like beta',
#  'classification': 'HORMONE/GROWTH FACTOR',
#  'organism': 'Mus musculus'}

# %%
df = pd.read_parquet("../website/backend/data/embed-sub-venome-2D.parquet")

# %%
pdb = df[df["name"].apply(lambda x: ("Gh" in x or "Lb" in x or "Lh" in x) and "comp" in x).apply(lambda x: not x)].copy()

# %%
codes = pdb["name"].apply(lambda x: x[3:7]).unique().tolist()

# %%
codes
# Out:
# ['1a5k',
#  '1avz',
#  '1ayb',
#  '1c7m',
#  '1dbd',
#  '1eod',
#  '1eoe',
#  '1eof',
#  '1f66',
#  '1fao',
#  '1fzv',
#  '1hdf',
#  '1j0f',
#  '1j6q',
#  '1jbi',
#  '1jnj',
#  '1jos',
#  '1jxg',
#  '1ka8',
#  '1klv',
#  '1ksr',
#  '1kx8',
#  '1mwq',
#  '1n8u',
#  '1no5',
#  '1nrv',
#  '1odd',
#  '1odv',
#  '1psr',
#  '1q8d',
#  '1r21',
#  '1ri0',
#  '1rja',
#  '1rn4',
#  '1ru0',
#  '1sru',
#  '1t1d',
#  '1u2n',
#  '1u36',
#  '1ub9',
#  '1uh6',
#  '1v4r',
#  '1ver',
#  '1w41',
#  '1w42',
#  '1wgr',
#  '1whd',
#  '1whv',
#  '1wjk',
#  '1wju',
#  '1wq8',
#  '1x0n',
#  '1x3a',
#  '1ylx',
#  '2a7o',
#  '2brf',
#  '2ce1',
#  '2ce6',
#  '2cgy',
#  '2cow',
#  '2cql',
#  '2cz4',
#  '2d9o',
#  '2dbf',
#  '2dn8',
#  '2do4',
#  '2dzm',
#  '2e2z',
#  '2e5n',
#  '2ebt',
#  '2edj',
#  '2edp',
#  '2eeh',
#  '2efi',
#  '2ep8',
#  '2es9',
#  '2g35',
#  '2gaq',
#  '2hlq',
#  '2hpl',
#  '2j4m',
#  '2jli',
#  '2jmp',
#  '2ka4',
#  '2kdg',
#  '2kjk',
#  '2kkc',
#  '2kpq',
#  '2kre',
#  '2kxy',
#  '2kz6',
#  '2l7p',
#  '2lc1',
#  '2lc7',
#  '2lfb',
#  '2lgv',
#  '2llz',
#  '2lv7',
#  '2lz0',
#  '2mqi',
#  '2mzt',
#  '2n8i',
#  '2nml',
#  '2p1b',
#  '2pbc',
#  '2r2o',
#  '2rkg',
#  '2rrm',
#  '2ubp',
#  '2vb5',
#  '2vwa',
#  '2vz4',
#  '2w3o',
#  '2w7a',
#  '2xrh',
#  '2yqe',
#  '2yre',
#  '2yuv',
#  '2yuz',
#  '2zxj',
#  '3aqz',
#  '3b5d',
#  '3bde',
#  '3bzp',
#  '3caf',
#  '3crd',
#  '3dhj',
#  '3dhm',
#  '3dj3',
#  '3ebn',
#  '3ekc',
#  '3fc7',
#  '3fhw',
#  '3foj',
#  '3fpu',
#  '3ft1',
#  '3ghf',
#  '3gk5',
#  '3gqs',
#  '3gt6',
#  '3hxa',
#  '3ib4',
#  '3if4',
#  '3iol',
#  '3k0x',
#  '3k2m',
#  '3k6f',
#  '3k8a',
#  '3kfj',
#  '3kor',
#  '3lhc',
#  '3mqc',
#  '3mzt',
#  '3n7p',
#  '3nxa',
#  '3nz3',
#  '3o5n',
#  '3ose',
#  '3q5o',
#  '3qda',
#  '3rcp',
#  '3rhb',
#  '3teq',
#  '3tlr',
#  '3u59',
#  '3ulc',
#  '3vh5',
#  '3vtt',
#  '4awj',
#  '4b6i',
#  '4cnz',
#  '4eai',
#  '4esf',
#  '4f2f',
#  '4fur',
#  '4fxl',
#  '4ios',
#  '4j7z',
#  '4lws',
#  '4lz2',
#  '4m8v',
#  '4mt8',
#  '4ogn',
#  '4p9v',
#  '4qsy',
#  '4r9h',
#  '4rfx',
#  '4rmq',
#  '4rmr',
#  '4rms',
#  '4rmt',
#  '4rmu',
#  '4rmv',
#  '4rmw',
#  '4u3h',
#  '4ue1',
#  '4uf8',
#  '4wil',
#  '4ye0',
#  '4yyg',
#  '5aea',
#  '5aos',
#  '5azx',
#  '5b08',
#  '5b0c',
#  '5b0d',
#  '5b0e',
#  '5b0f',
#  '5b0g',
#  '5b8d',
#  '5bqc',
#  '5cka',
#  '5ckg',
#  '5csg',
#  '5d13',
#  '5dhe',
#  '5f99',
#  '5fig',
#  '5hi3',
#  '5hj0',
#  '5ifg',
#  '5ii6',
#  '5in7',
#  '5j6p',
#  '5m6n',
#  '5nan',
#  '5o2p',
#  '5tnw',
#  '5u1q',
#  '5umr',
#  '5vfx',
#  '5w82',
#  '5xpv',
#  '5zb6',
#  '6a2s',
#  '6aq7',
#  '6b3n',
#  '6b87',
#  '6bhw',
#  '6cec',
#  '6d12',
#  '6dg6',
#  '6do0',
#  '6fuu',
#  '6gl7',
#  '6h0j',
#  '6i0q',
#  '6i6w',
#  '6ial',
#  '6ije',
#  '6is4',
#  '6jmi',
#  '6kyx',
#  '6l1t',
#  '6la2',
#  '6ls1',
#  '6m1b',
#  '6oqm',
#  '6vgb',
#  '6wm1',
#  '6x39',
#  '6x7h',
#  '6xpk',
#  '6yrb',
#  '6yud',
#  '6z26',
#  '6zdx',
#  '7cg5',
#  '7cnc',
#  '7d2q',
#  '7epg',
#  '7evr',
#  '7fcn',
#  '7jpp',
#  '7kld',
#  '7m5t',
#  '7nd1',
#  '7obj',
#  '7p62',
#  '7qri',
#  '7qz7',
#  '7r47',
#  '7r4w',
#  '7sfz',
#  '7v96',
#  '7w05',
#  '7x5f',
#  '7y54',
#  '7y95',
#  '7yi1',
#  '7ypl',
#  '8au4',
#  '8b8d',
#  '8bx2',
#  '8bxj',
#  '8dqa',
#  '8hxs',
#  '8p35',
#  '8uf0',
#  '1aud',
#  '1aya',
#  '1bft',
#  '1cqk',
#  '1d1z',
#  '1d7m',
#  '1egj',
#  '1f39',
#  '1fj7',
#  '1hhn',
#  '1hjd',
#  '1iiy',
#  '1jhg',
#  '1jnp',
#  '1kca',
#  '1l8r',
#  '1lm0',
#  '1lom',
#  '1lyq',
#  '1m2b',
#  '1m2d',
#  '1m31',
#  '1mdv',
#  '1mg4',
#  '1n8v',
#  '1nsh',
#  '1nwb',
#  '1nzl',
#  '1p1e',
#  '1puc',
#  '1qbh',
#  '1qc7',
#  '1qo6',
#  '1qsv',
#  '1rki',
#  '1se9',
#  '1shd',
#  '1sqe',
#  '1u42',
#  '1uez',
#  '1umj',
#  '1v32',
#  '1v63',
#  '1vcr',
#  '1vhf',
#  '1wh6',
#  '1wiz',
#  '1wj6',
#  '1wvz',
#  '1x2l',
#  '1xma',
#  '1xn9',
#  '1xo3',
#  '1xz9',
#  '1y0h',
#  '1yze',
#  '1zdx',
#  '1zt9',
#  '2a1b',
#  '2a3s',
#  '2ask',
#  '2asy',
#  '2b1y',
#  '2bo1',
#  '2byu',
#  '2cq1',
#  '2cqk',
#  '2csf',
#  '2cup',
#  '2do7',
#  '2e5e',
#  '2e60',
#  '2edk',
#  '2eed',
#  '2enk',
#  '2fc9',
#  '2fls',
#  '2ghj',
#  '2gr7',
#  '2h7d',
#  '2h9u',
#  '2hio',
#  '2hj3',
#  '2huw',
#  '2hvz',
#  '2hwv',
#  '2i1n',
#  '2j9w',
#  '2ja4',
#  '2jik',
#  '2jon',
#  '2jun',
#  '2k5h',
#  '2kjv',
#  '2kom',
#  '2kw2',
#  '2kwa',
#  '2l6m',
#  '2la4',
#  '2lai',
#  '2lea',
#  '2lf6',
#  '2lse',
#  '2luw',
#  '2m8h',
#  '2mbf',
#  '2mh7',
#  '2mjm',
#  '2mrd',
#  '2mzq',
#  '2n59',
#  '2n5g',
#  '2npu',
#  '2oa4',
#  '2od4',
#  '2ov6',
#  '2p5p',
#  '2pe8',
#  '2pys',
#  '2qkw',
#  '2qsa',
#  '2qzi',
#  '2rp3',
#  '2rrd',
#  '2vub',
#  '2wkf',
#  '2xi1',
#  '2yt7',
#  '2zdi',
#  '3aqx',
#  '3b76',
#  '3bzt',
#  '3cby',
#  '3cm7',
#  '3eac',
#  '3f8b',
#  '3faj',
#  '3ff8',
#  '3hj5',
#  '3hx9',
#  '3ie4',
#  '3jss',
#  '3juz',
#  '3jv0',
#  '3jv4',
#  '3l5x',
#  '3lfo',
#  '3m45',
#  '3m8e',
#  '3m9e',
#  '3mq1',
#  '3mup',
#  '3mxy',
#  '3nxb',
#  '3oq0',
#  '3ove',
#  '3qik',
#  '3qp3',
#  '3sb3',
#  '3soe',
#  '3ssq',
#  '3u1c',
#  '3ui4',
#  '3unm',
#  '3vdy',
#  '3who',
#  '3wrp',
#  '3zq7',
#  '3zrf',
#  '4b9k',
#  '4bz2',
#  '4c53',
#  '4e74',
#  '4eih',
#  '4ekx',
#  '4ety',
#  '4fhq',
#  '4inc',
#  '4j4c',
#  '4jfn',
#  '4llm',
#  '4lx3',
#  '4nn6',
#  '4o8b',
#  '4odp',
#  '4ox7',
#  '4p6i',
#  '4pky',
#  '4q56',
#  '4q9b',
#  '4qcj',
#  '4qfq',
#  '4qkv',
#  '4qkw',
#  '4rt5',
#  '4uf9',
#  '4ui0',
#  '4uit',
#  '4w9c',
#  '4yx2',
#  '4yxh',
#  '4yxk',
#  '4yy4',
#  '4zgl',
#  '5amu',
#  '5b1c',
#  '5b42',
#  '5bqe',
#  '5bxd',
#  '5bxh',
#  '5cke',
#  '5e2x',
#  '5eo3',
#  '5evg',
#  '5fm4',
#  '5fta',
#  '5hdn',
#  '5hrj',
#  '5hs8',
#  '5ils',
#  '5izw',
#  '5j7f',
#  '5kgf',
#  '5kh3',
#  '5ko4',
#  '5mpy',
#  '5mr1',
#  '5mti',
#  '5nmz',
#  '5otx',
#  '5szw',
#  '5tq1',
#  '5ts4',
#  '5ty4',
#  '5w72',
#  '5w7x',
#  '5yuo',
#  '5z8q',
#  '5z9z',
#  '5za3',
#  '5zc1',
#  '5zqh',
#  '6eb9',
#  '6fgg',
#  '6fw4',
#  '6ijf',
#  '6iqo',
#  '6j05',
#  '6j6y',
#  '6jdg',
#  '6kc4',
#  '6kos',
#  '6l1r',
#  '6lje',
#  '6lpa',
#  '6mbi',
#  '6nlu',
#  '6nuk',
#  '6o35',
#  '6pog',
#  '6py0',
#  '6qqk',
#  '6r8y',
#  '6rib',
#  '6s92',
#  '6sv2',
#  '6wdz',
#  '6yig',
#  '6yx0',
#  '6zgn',
#  '6zu9',
#  '7dcu',
#  '7ea5',
#  '7ea8',
#  '7enm',
#  '7epj',
#  '7evs',
#  '7kd3',
#  '7kjo',
#  '7p69',
#  '7p7c',
#  '7q34',
#  '7r22',
#  '7r45',
#  '7r46',
#  '7sgn',
#  '7syq',
#  '7uzo',
#  '7vxr',
#  '7wh4',
#  '7win',
#  '8ah6',
#  '8ehd',
#  '8ezr',
#  '8hxy',
#  '8oiy',
#  '8orf',
#  '8oty',
#  '8ovw',
#  '8sza',
#  '1b79',
#  '1bhu',
#  '1bkm',
#  '1c8p',
#  '1cww',
#  '1d0q',
#  '1d2z',
#  '1e2a',
#  '1eqk',
#  '1fhg',
#  '1g10',
#  '1go0',
#  '1is0',
#  '1iuj',
#  '1ix2',
#  '1j03',
#  '1j2v',
#  '1jd6',
#  '1jjg',
#  '1jt8',
#  '1kdi',
#  '1kkx',
#  '1l3p',
#  '1m42',
#  '1n02',
#  '1nci',
#  '1p13',
#  '1p1l',
#  '1p68',
#  '1qa9',
#  '1qbz',
#  '1qsd',
#  '1qw2',
#  '1r57',
#  '1s62',
#  '1sjv',
#  '1ss6',
#  '1svy',
#  '1td0',
#  '1tpx',
#  '1tqb',
#  '1tqc',
#  '1tul',
#  '1uku',
#  '1ul7',
#  '1uwd',
#  '1uz3',
#  '1v1i',
#  '1v5o',
#  '1vcs',
#  '1vh6',
#  '1w0b',
#  '1wez',
#  '1whh',
#  '1whj',
#  '1wrp',
#  '1wz7',
#  '1x0g',
#  '1x4d',
#  '1x5s',
#  '1xu0',
#  '1yel',
#  '1yv7',
#  '1ywx',
#  '1z9v',
#  '2bz7',
#  '2ci9',
#  '2co9',
#  '2cqb',
#  '2ctf',
#  '2d1h',
#  '2d7h',
#  '2d90',
#  '2da6',
#  '2dbh',
#  '2dge',
#  '2dk6',
#  '2dlg',
#  '2dno',
#  '2e66',
#  '2eby',
#  '2edr',
#  '2edt',
#  '2eo1',
#  '2fc8',
#  '2feb',
#  '2ff0',
#  '2fsw',
#  '2ghf',
#  '2gol',
#  '2he2',
#  '2hgl',
#  '2i7f',
#  '2ida',
#  '2j71',
#  '2j9d',
#  '2jin',
#  '2job',
#  '2jua',
#  '2k3g',
#  '2k8h',
#  '2k9x',
#  '2kbg',
#  '2kgj',
#  '2kif',
#  '2kkx',
#  '2km7',
#  '2kmc',
#  '2kou',
#  '2kt7',
#  '2l3d',
#  '2l50',
#  '2l6a',
#  '2l9f',
#  '2lv3',
#  '2m5v',
#  '2mct',
#  '2md5',
#  '2mez',
#  '2mqg',
#  '2ms7',
#  '2mwc',
#  '2nar',
#  '2nco',
#  '2no2',
#  '2np2',
#  '2npt',
#  '2oie',
#  '2oya',
#  '2p9r',
#  '2qyc',
#  '2r4q',
#  '2rqe',
#  '2v6s',
#  '2v8q',
#  '2wbx',
#  '2ya3',
#  '2yrl',
#  '2yv4',
#  '2z21',
#  '3ady',
#  '3b94',
#  '3bn7',
#  '3cao',
#  '3d82',
#  '3e7h',
#  '3e8o',
#  '3eaz',
#  '3eq5',
#  '3fog',
#  '3fov',
#  '3heq',
#  '3hhh',
#  '3isu',
#  '3iwh',
#  '3kav',
#  '3kd7',
#  '3kh0',
#  '3kt9',
#  '3l8r',
#  '3leq',
#  '3lr0',
#  '3lyy',
#  '3nrf',
#  '3o8v',
#  '3oa1',
#  '3oqy',
#  '3ov1',
#  '3phd',
#  '3q3j',
#  '3qe1',
#  '3syu',
#  '3t72',
#  '3ueb',
#  '3ulb',
#  '3wvt',
#  '3ztd',
#  '3zun',
#  '4afl',
#  '4ba8',
#  '4bgc',
#  '4bks',
#  '4c1m',
#  '4cw9',
#  '4dot',
#  '4dpo',
#  '4e3b',
#  '4e45',
#  '4eb9',
#  '4eqq',
#  '4ew5',
#  '4f37',
#  '4fa0',
#  '4fei',
#  '4h11',
#  '4h88',
#  '4i86',
#  '4ini',
#  '4irh',
#  '4ixa',
#  '4jdq',
#  '4jdx',
#  '4je4',
#  '4k45',
#  '4kdv',
#  '4n8n',
#  '4nbo',
#  '4nhj',
#  '4nnr',
#  '4nxg',
#  '4o00',
#  '4o06',
#  '4p7u',
#  '4pbd',
#  '4pqp',
#  '4u17',
#  '4uht',
#  '4umg',
#  '4whi',
#  '4yy6',
#  '5a6r',
#  '5aot',
#  '5bok',
#  '5cbf',
#  '5cqy',
#  '5d4l',
#  '5d4p',
#  '5h0p',
#  '5hbo',
#  '5hs7',
#  '5i2o',
#  '5icu',
#  '5ir0',
#  '5ixu',
#  '5jaa',
#  '5kz9',
#  '5lli',
#  '5ml1',
#  '5mn3',
#  '5mpl',
#  '5otv',
#  '5t2q',
#  '5tz0',
#  '5v84',
#  '5vfy',
#  '5vkd',
#  '5vwk',
#  '5wpb',
#  '5yyz',
#  '5z42',
#  '5zhc',
#  '6dgj',
#  '6dy3',
#  '6ekp',
#  '6f7f',
#  '6gmn',
#  '6gn9',
#  '6h0q',
#  '6hj7',
#  '6jui',
#  '6l80',
#  '6mtu',
#  '6mup',
#  '6nyp',
#  '6pol',
#  '6qbi',
#  '6qvp',
#  '6roy',
#  '6s93',
#  '6s94',
#  '6s95',
#  '6t7e',
#  '6xjf',
#  '6ywz',
#  '6z2b',
#  '7amg',
#  '7bla',
#  '7blc',
#  '7bxh',
#  '7c20',
#  '7clt',
#  '7ctf',
#  '7eeq',
#  '7et4',
#  '7et6',
#  '7ey7',
#  '7fad',
#  '7jk8',
#  '7jtl',
#  '7kjz',
#  '7l0j',
#  '7lu6',
#  '7lv8',
#  '7mp3',
#  '7p64',
#  '7pgl',
#  '7qz6',
#  '7rqg',
#  '7sgo',
#  '7sgt',
#  '7syv',
#  '7t1k',
#  '7tlx',
#  '7txo',
#  '7v9h',
#  '7xfg',
#  '7y7i',
#  '8ah5',
#  '8ap4',
#  '8bdo',
#  '8dyf',
#  '8ehb',
#  '8ezs',
#  '8h1g',
#  '8i6v',
#  '8jhg',
#  '8szb',
#  '1a5r',
#  '1ag2',
#  '1ag4',
#  '1ayf',
#  '1b0n',
#  '1b98',
#  '1cyc',
#  '1det',
#  '1f68',
#  '1f93',
#  '1fim',
#  '1gv2',
#  '1gxp',
#  '1h7c',
#  '1i3z',
#  '1i54',
#  '1i7a',
#  '1iib',
#  '1j8c',
#  '1jm7',
#  '1l8d',
#  '1m2a',
#  '1mda',
#  '1mi7',
#  '1n7t',
#  '1nza',
#  '1pul',
#  '1q4r',
#  '1r5x',
#  '1r6y',
#  '1r7l',
#  '1reu',
#  '1rew',
#  '1rn1',
#  '1s6d',
#  '1s79',
#  '1s7a',
#  '1sha',
#  '1syr',
#  '1td3',
#  '1te7',
#  '1tfo',
#  '1tlk',
#  '1u41',
#  '1u78',
#  '1ub4',
#  '1uep',
#  '1ufx',
#  '1v1h',
#  '1v5l',
#  '1v9y',
#  '1vr4',
#  '1w9g',
#  '1wcr',
#  '1wf7',
#  '1wfv',
#  '1wjt',
#  '1wuz',
#  '1wwb',
#  '1x44',
#  '1xer',
#  '1y9o',
#  '1yn5',
#  '1zld',
#  '1zle',
#  '2arw',
#  '2bbe',
#  '2cq0',
#  '2cq3',
#  '2cqg',
#  '2cqi',
#  '2cu1',
#  '2czn',
#  '2d1v',
#  '2d9p',
#  '2dbg',
#  '2dgu',
#  '2dku',
#  '2dl9',
#  '2dng',
#  '2dnm',
#  '2e3v',
#  '2e7b',
#  '2e8o',
#  ...]

# %%
def flatten(arr):
  out = []
  def _flatten(a):
    for item in a:
      if isinstance(item, list):
        _flatten(item)
      else:
        out.append(item)
  _flatten(arr)
  return out

def graphql_pdb(code: str):
  query = """
  query structure ($id: String!) {
    entry(entry_id:$id){
        struct {
            title
        }
        struct_keywords {
            pdbx_keywords
        }
        polymer_entities {
            rcsb_entity_source_organism {
              scientific_name
            }
          }
    }
  }
  """
  output = requests.post("https://data.rcsb.org/graphql", json={"query": query, "variables": {"id": code}}).json()
  root = output["data"]["entry"]
  if root is None:
    return None, None, None

  title = None
  if "struct" in root and root["struct"] is not None:
    title = root["struct"]
    
  pdbx_keywords = None
  if "struct_keywords" in root and root["struct_keywords"] is not None:
    if "pdbx_keywords" in root["struct_keywords"] and root["struct_keywords"]["pdbx_keywords"] is not None:
      pdbx_keywords = root["struct_keywords"]["pdbx_keywords"]

  organisms = []
  if "polymer_entities" in root and root["polymer_entities"] is not None:
    for polymer_entities in root["polymer_entities"]:
      rcsb_entity_source_organism = polymer_entities["rcsb_entity_source_organism"]
      if rcsb_entity_source_organism is None:
        continue
      else:
        for _org in rcsb_entity_source_organism:
          organisms.append(_org["scientific_name"])

  return title, pdbx_keywords, list(set(organisms))

# %%
infos = []
for c in tqdm(codes):
	infos.append(graphql_pdb(c))
	
print(infos)
# Out:
#  44%|████▎     | 46174/105757 [2:06:11<2:42:50,  6.10it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 3
#       1 infos = []
#       2 for c in tqdm(codes):
# ----> 3 	infos.append(graphql_pdb(c))
#       5 print(infos)
#
# Cell In[15], line 30, in graphql_pdb(code)
#      12 def graphql_pdb(code: str):
#      13   query = """
#      14   query structure ($id: String!) {
#      15     entry(entry_id:$id){
#    (...)
#      28   }
#      29   """
# ---> 30   output = requests.post("https://data.rcsb.org/graphql", json={"query": query, "variables": {"id": code}}).json()
#      31   root = output["data"]["entry"]
#      32   if root is None:
#
# File /usr/local/lib/python3.11/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /usr/local/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /usr/local/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /usr/local/lib/python3.11/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /usr/local/lib/python3.11/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /usr/local/lib/python3.11/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /usr/local/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1386, in HTTPConnection.getresponse(self)
#    1384 try:
#    1385     try:
# -> 1386         response.begin()
#    1387     except ConnectionError:
#    1388         self.close()
#
# File /usr/local/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File /usr/local/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File /usr/local/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /usr/local/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1315, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1311     if flags != 0:
#    1312         raise ValueError(
#    1313           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1314           self.__class__)
# -> 1315     return self.read(nbytes, buffer)
#    1316 else:
#    1317     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/local/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
titles = [i[0] for i in infos]
keywords = [i[1] for i in infos]
organisms = [i[2] for i in infos]
pd.DataFrame({"code": codes, "title": titles, "keywords": keywords, "organisms": organisms }).to_parquet("pdb-info.parquet", index=False)
